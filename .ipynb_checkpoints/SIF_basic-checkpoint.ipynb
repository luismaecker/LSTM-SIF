# %%
from xcube.core.store import new_data_store
store = new_data_store("s3", root="deep-esdl-public", storage_options=dict(anon=True))
ds = store.open_data('esdc-8d-0.25deg-1x720x1440-3.0.1.zarr')

# %%
variables = ["sif_gosif", "evaporation_era5", "precipitation_era5", "radiation_era5", "air_temperature_2m", "max_air_temperature_2m", "min_air_temperature_2m"]

# %%
ds_selected = ds[variables].sel(time=slice("2001-01-05T00:00:00.000000000","2020-12-30T00:00:00.000000000"),lat=lat_bounds, lon=lon_bounds )

# Define the geographical bounds for Central Europe (approximate)
lat_bounds = slice(30, 60)  # Latitude range
lon_bounds = slice(-10, 30)  # Longitude range

# Select the specific region and variable
central_europe_sif = ds_step['sif_gosif'].sel(lat=lat_bounds, lon=lon_bounds)
ds_selected
# Out:
# <xarray.Dataset> Size: 165MB
# Dimensions:                 (time: 920, lat: 40, lon: 160)
# Coordinates:
#   * lat                     (lat) float64 320B 45.12 45.38 45.62 ... 54.62 54.88
#   * lon                     (lon) float64 1kB -9.875 -9.625 ... 29.62 29.88
#   * time                    (time) datetime64[ns] 7kB 2001-01-05 ... 2020-12-30
# Data variables:
#     sif_gosif               (time, lat, lon) float32 24MB dask.array<chunksize=(1, 40, 160), meta=np.ndarray>
#     evaporation_era5        (time, lat, lon) float32 24MB dask.array<chunksize=(1, 40, 160), meta=np.ndarray>
#     precipitation_era5      (time, lat, lon) float32 24MB dask.array<chunksize=(1, 40, 160), meta=np.ndarray>
#     radiation_era5          (time, lat, lon) float32 24MB dask.array<chunksize=(1, 40, 160), meta=np.ndarray>
#     air_temperature_2m      (time, lat, lon) float32 24MB dask.array<chunksize=(1, 40, 160), meta=np.ndarray>
#     max_air_temperature_2m  (time, lat, lon) float32 24MB dask.array<chunksize=(1, 40, 160), meta=np.ndarray>
#     min_air_temperature_2m  (time, lat, lon) float32 24MB dask.array<chunksize=(1, 40, 160), meta=np.ndarray>
# Attributes: (12/23)
#     Conventions:                CF-1.9
#     acknowledgment:             All ESDC data providers are acknowledged insi...
#     contributor_name:           ['University of Leipzig', 'Max Planck Institu...
#     contributor_url:            ['https://www.uni-leipzig.de/', 'https://www....
#     creator_name:               ['University of Leipzig', 'Brockmann Consult ...
#     creator_url:                ['https://www.uni-leipzig.de/', 'https://www....
#     ...                         ...
#     publisher_url:              https://www.earthsystemdatalab.net/
#     time_coverage_end:          2021-12-31T00:00:00.000000000
#     time_coverage_start:        1979-01-05T00:00:00.000000000
#     time_period:                8D
#     time_period_reported_day:   5.0
#     title:                      Earth System Data Cube (ESDC) v3.0.1

# %%
import xarray as xr
import matplotlib.pyplot as plt
ds_step = ds_selected.sel(time="2001-01-05T00:00:00.000000000")



# Plotting
plt.figure(figsize=(10, 8))
central_europe_gpp.plot(cmap='viridis')
plt.title('sif_gosif on 2001-01-05')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()
